# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from plotnine import *
from plotnine.data import mtcars

# %matplotlib inline

# (ggplot(mtcars,aes(x="wt",y="mpg",color = "factor(gear)"))+geom_point()+stat_smooth(method="lm")
# #  +facet_wrap("~gear")
# )
penguin = pd.read_csv('/Users/aidanwall/Documents/CPSC_Courses/CPSC_392/CPSC392ParlettPelleriti/Data/penguins.csv')
print(penguin.head())

(ggplot(penguin,aes(x="bill_length_mm",
                    y="bill_depth_mm",color="species"))+geom_point())
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           0  Adelie  Torgersen            39.1           18.7
# 1           1  Adelie  Torgersen            39.5           17.4
# 2           2  Adelie  Torgersen            40.3           18.0
# 3           3  Adelie  Torgersen             NaN            NaN
# 4           4  Adelie  Torgersen            36.7           19.3
#
#    flipper_length_mm  body_mass_g     sex  year
# 0              181.0       3750.0    male  2007
# 1              186.0       3800.0  female  2007
# 2              195.0       3250.0  female  2007
# 3                NaN          NaN     NaN  2007
# 4              193.0       3450.0  female  2007
# <ggplot: (323433259)>

# %%
(ggplot(penguin,aes(x="species",y="bill_length_mm",fill="species"))+geom_boxplot())
# Out:
# <ggplot: (323695585)>

# %%
(ggplot(penguin,aes(x="species",y="bill_length_mm",fill="species"))+geom_boxplot()+theme_minimal()+geom_point())
# Out:
# <ggplot: (-9223372036529796576)>

# %%
(ggplot(penguin,aes(x="species",y="body_mass_g",fill="species"))+stat_summary(fun_data="mean_sdl",geom="bar")+ggtitle("mean_body_mass"))
# Out:
# <ggplot: (-9223372036529758520)>

# %%
cereal = pd.read_csv('/Users/aidanwall/Documents/CPSC_Courses/CPSC_392/CPSC392ParlettPelleriti/Data/cereal.csv')
# print(cereal.head())
(ggplot(cereal,aes(x="mfr",))+geom_bar(aes(fill="mfr"))+theme_bw())
# Out:
# <ggplot: (-9223372036531084747)>

# %%
(ggplot(cereal,aes(x="protein",y="sugars"))+geom_point()+facet_wrap("~mfr")+theme_bw())
# Out:
# <ggplot: (-9223372036530610979)>
